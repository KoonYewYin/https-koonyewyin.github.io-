# %%
<!DOCTYPE html>
<html>
<head>
    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
    <meta name="renderer" content="webkit">
    <meta http-equiv="X-UA-Compatible" content="IE=Edge">
    <meta name="keywords" content="大数据,股票,大数据诊股,投资分析,预测">
    <meta name="description" content="中富金石专业投资分析师整合大数据，预测股票走势，警示潜在风险，揭秘主力底牌，让投资更简单！">
    <title>免费送好股</title>
    <link rel="stylesheet" type="text/css" href="static/css/animate.min.css">
    <style type="text/css">
        * {margin:0;padding:0;font-family:'思源黑体';}
        .layui-layer-hui .layui-layer-content{padding: 24px 32px!important}
        .layui-layer-dialog .layui-layer-content{font-size: 36px!important;line-height: 40px!important;}
        html{background-color: #ec453c}
        .headimg {width:100%;background:url("static/image/bg.jpg");background-position:center center;}
        .headContent {width:1000px;height:153px;padding-top:500px;margin:0 auto;position:relative;overflow:hidden;}
        .headBtn {width:342px;height:75px;margin:0 auto;cursor:pointer;background:url("static/image/headBtn.png") no-repeat;background-size:100% 100%;}
        .middiv {position:relative;margin:auto;}
        .quota {width:100%;height:318px;background-color:#ececeb;}
        .quota .center {width:1000px;margin:0 auto;}
        .option4_{background-image: url('static/image/cp2.png');width: 1000px;height: 183px;margin: 0 auto;position:relative;background-size: 1000px 183px;}
        .option4_>div{display: inline-block;width: 145px;height: 45px;position: absolute;cursor: pointer;background-image: url('static/image/qiang.png');z-index: 50;}
        .option1{left: 290px;top: 17px;}
        .option2{left: 810px;top: 17px;}
        .option3{left: 290px;top: 124px;}
        .option4{left: 810px;top: 124px;}
        .follow_bg {width:100%;height:618px;background:url("static/image/follow_bg.jpg") no-repeat;background-position:center center;background-size:100% 100%;}
        .follow {width:1000px;margin:0 auto;}
        .zangtablediv {margin-bottom:20px;}
        .center {text-align:center;}
        .zangimgdiv{width:460px;height:261px;float:left;}
        .zangimgdiv img{display: block;width: 100%;height: 100%;}
        .stocktable {width:538px;height:259px;}
        .stocktable td {font-size:18px;text-align:center;color:#020202;border-bottom:1px solid #f6c086;border-right:1px solid #f6c086;}
        .stocktable  .djck {font-size:16px;color:#fc1103;cursor:pointer;}
        .stocktable .stocktable_name,.stocktable .stocktable_time {font-size:16px;}
        .btn2 {cursor:pointer;margin-top:12px;}
        .team_box {width:100%;height:604px;margin-top:37px;background:url("static/image/team.jpg") no-repeat;background-size:100% 100%;background-position:center center;}
        .team {position:absolute;top:0;left:0;width:507px;height:344px;background:url(static/image/team2.jpg) no-repeat;background-size:507px 410px;background-position: center -30px;}
        .table2{width:96%;margin-left:2%;text-align:center;}
        .table2 tr{height:49px;background-color:#fddbaa;}
        .table2 td{border:1px solid #f9bc93;color: #000000;}
        .table2 .red{color: #ff0000;}
        .btn3{cursor: pointer;margin-bottom: 5px;}
        .quantity {font-size:26px;color:#ffffff;margin:28px auto;}
        .quantity span {color:#ffea00;}
        .product {width:999px;height:160px;margin:0 auto;background:url("static/image/product.png") no-repeat;background-size:100% 100%;}
        .product p {width:232px;height:160px;float:left;margin-right:22px;cursor:pointer;background:url("static/image/product_btn.png") no-repeat;background-position:48px 118px;background-size:144px 33px;}
        .product p:last-child {margin-right:0;}
        input{border:none;outline: none;}
        .zhegai {width:100%;height:100%;background-color:rgba(0,0,0,0.8);position:fixed;top:0;left:0;z-index:99;cursor:pointer;display:none;}
        .dialog1 {position:fixed;top:50%;left:50%;width:670px;height:525px;margin-left:-335px;margin-top:-296px;background:url(static/image/dialog1.png) no-repeat;z-index:101;display:none;}
        .dialog1 .circle1 {width:51px;height:51px;position:absolute;right:0;top:-70px;cursor:pointer;background:url(https://www.zx017.net/z/x2/imgs/circle1.png) no-repeat;}
        .dialog1 .result {color:#666666;margin-top:32px;font-size:36px;}
        .dialog1 .result .cName {color:#f90303;font-size:44px;font-weight:bold;margin-right:5px;}
        .dialog1 .according {margin:14px auto 0;font-size:29px;color:#333;line-height:1.6;text-align: center;}
        .dialog1 .inputBlock {padding-top:8px;padding-bottom:12px;}
        .dialog1 .dialog1_input {display:block;width:588px;height:90px;line-height:90px;border:1px solid #b5b5b5;outline:0;background-color:#eeeeee;margin:16px auto 0;font-size:40px;border-radius:25px;}
        .dialog1 .dialog1_btn {width:589px;height:98px;line-height:92px;font-weight:bold;font-size:48px;color:#fff600;cursor:pointer;margin:13px auto 0;background:url("static/image/dialog1_btn.png") no-repeat;}
        .dialog1 .promise {color:#666666;font-size:24px;}
        .dialog2 {position:fixed;top:50%;left:50%;width:640px;height:768px;margin-top:-384px;margin-left:-320px;background:url("static/image/dialog2.png") no-repeat;z-index:101;display:none;}
        .dialog2 .circle2,.dialog3 .circle3 {position:absolute;top:32px;right:0;width:47px;height:47px;cursor:pointer;background:url("static/image/circle2.png") no-repeat;}
        .dialog2 .dialog_txt {margin:143px auto 0;}
        .dialog2 .txt1 {width:410px;height:151px;background:url("static/image/ztzg.png") no-repeat;}
        .dialog2 .txt2 {width:406px;height:150px;background:url("static/image/cp3.png") no-repeat;}
        .dialog2 .txt5 {width:404px;height:148px;background:url("static/image/zgzt.png") no-repeat;}
        .dialog2 .txt6 {width:402px;height:144px;background:url("static/image/yzg.png") no-repeat;}
        .dialog2 .prompt {width:520px;height:26px;font-size:25px;color:#ffffff;padding-left:32px;margin:84px auto 0;text-align: center;}
        .dialog_input {display:block;outline:none;border:none;font-size:31px;background:#fff;border-radius:26px;}
        .dialog2 .dialog2_input {width:475px;height:95px;line-height:95px;margin:35px auto 0;}
        .dialog2_btn {width:469px;height:101px;line-height:101px;margin:13px auto 0;color:#d71519;font-weight:bold;font-size:46px;text-align:center;cursor:pointer;background-color:#ffdc1d;border-radius:14px;}
        .promise {margin-top:24px;font-size:23px;color:#ffffff;}
        .dialog3 {position:fixed;top:50%;left:50%;width:640px;height:768px;margin-top:-384px;margin-left:-320px;background:url("static/image/dialog3.png") no-repeat;z-index:101;display:none;}
        .dialog3 .dialog_txt {margin:66px auto 0;}
        .dialog3 .txt3 {width:352px;height:135px;background:url("static/image/tgzj.png") no-repeat;}
        .dialog3 .txt4 {width:385px;height:137px;background:url("static/image/agzbj.png") no-repeat;}
        .dialog3 .txt5 {width:308px;height:162px;padding-top:45px;background:url("static/image/cp4.png") no-repeat;}
        .dialog3 .dialog3_num {width:340px;height:48px;color:#040100;font-size:40px;margin:0 auto;margin-top:25px;}
        .dialog3 .dialog3_input,.dialog4 .dialog4_input {width:490px;height:99px;line-height:99px;margin:83px auto 0;}
        .dialog3 .dialog3_btn,.dialog4 .dialog4_btn {width:490px;height:106px;line-height:106px;margin:24px auto 0;color:#d71519;font-weight:bold;font-size:46px;text-align:center;cursor:pointer;background-color:#ffdc1d;border-radius:14px;}
        .dialog4 {position:fixed;top:50%;left:50%;width:678px;height:709px;margin-top:-354px;margin-left:-339px;background:url("static/image/dialog4.png") no-repeat;z-index:101;display:none;}
        .dialog4 .circle4 {position:absolute;top:32px;right:0;width:50px;height:49px;cursor:pointer;background:url("static/image/circle4.png") no-repeat;}
        .dialog4 .dialog_txt {width:338px;height:76px;margin:95px auto 0;}
        .dialog4  .txt7 {background:url("static/image/jsyt.png") no-repeat;}
        .dialog4  .txt8 {background:url("static/image/cp5.png") no-repeat;}
        .dialog4  .txt9 {background:url("static/image/sxcp.png") no-repeat;}
        .dialog4  .txt10 {background:url("static/image/srdz.png") no-repeat;}
        .dialog4 .dialog4_num {width:420px;height:38px;margin:48px auto 0;background:url("static/image/dialog4_num.png") no-repeat;}
        .animated_02 {animation:pulse2  1.2s linear infinite;-webkit-animation:pulse2 1.2s linear infinite;-webkit-animation-fill-mode:both;animation-fill-mode:both;z-index:100;}
        @-webkit-keyframes pulse2 {
            0% {-webkit-transform:scale(0.9);}
            50% {-webkit-transform:scale(1);}
            100% {-webkit-transform:scale(0.9);}
        }
        @keyframes pulse2 {
            0% {transform:scale(0.9)}
            50% {transform:scale(1)}
            100% {transform:scale(0.9)}
        }
        .bottom_div {position:fixed;bottom:0;width:100%;background-color:#90111a;height:112px;padding-top:17px;z-index:80;min-width:1000px;}
        .bottom_cs {position:fixed;bottom:0;left:20%;}
        .bottom_input_div {width:500px;margin-left:-250px;position:absolute;left:50%;}
        .bottom_input_div2 {width:360px;float:left;}
        .stockname {width:130%;height:55px;margin-top:4px;font-size:20px;padding-left:16px;}
        .bottom_input_btn {width:130px;float:left;margin-top:4px;height:60px;cursor:pointer;}
        .ce_div {position:fixed;bottom:45%;right:10px;z-index:2;}
        .team_title{width: 999px;height: 57px;line-height: 57px;color: #fdeba9;font-size: 28px;font-weight: bold;text-align: center; margin: auto auto 12px;background: url("static/image/t3.png") no-repeat;}

		.dialog5 {display:none;position:fixed;top:50%;left:50%;width:442px;height:557px;padding-top:40px;margin:-298px auto auto -221px;background:url("static/image/dialog5.png") no-repeat center center/100% 100%;z-index:101;}
        .dialog5 .circle5{position:absolute;top:620px;left:50%;width:53px;height:53px;margin-left:-26px;background:url("static/image/circle5.png") no-repeat center center/100% 100%;cursor:pointer;}
        .dialog5 .cName {height:56px;line-height:56px;font-size:56px;color:#ec5e3e;text-align:center;font-weight:bold;}
        .dialog5 .cName_info {width: 392px;line-height:28px;font-size:24px;text-align:center;color:#988784;margin:10px auto 0;}
        .dialog5 .tip1 {height:32px;line-height:32px;font-size:24px;color:#895026;text-align:center;margin-top:23px;}
        .dialog5 .tip1 i {display:inline-block;width:32px;height:32px;vertical-align:top;margin-right:10px;background:url("static/image/wx.png") no-repeat center center/100% 100%;}
        .dialog5 .tip2 {height:19px;line-height:19px;font-size:19px;color:#444442;text-align:center;margin-top:12px;}
        .dialog5 .tip2 .cName {height:19px;line-height:19px;color:#ef4822;font-size:19px;font-weight:normal;}
        .dialog5 .tip3 {width:300px;height:20px;line-height:20px;text-align:center;margin:12px auto 0;color:#ef4822;font-size:18px;background:url("static/image/star.png") no-repeat center center/100% 100%;}
        .dialog5 .moreInfo_QR_box {width:257px;height:250px;padding-top: 5px;margin:12px auto 7px;background-color: #ffffff;border:1px solid #c68554;}
        .dialog5 .moreInfo_QR {display:block;width:247px;height:245px;margin: 0 auto;}
        .dialog5 .tip4 {height:16px;line-height:16px;color:#de0304;text-align:center;}
        .dialog5 .tip4 i {display:inline-block;width:20px;height:20px;vertical-align:top;margin-right:10px;background:url("static/image/safe.png") no-repeat center center/100% 100%;}
		.dialog6 {position:fixed;top:50%;left:50%;width:386px;height:501px;margin:-250px auto auto -193px;background:url("static/image/dialog6.png") no-repeat center center/100% 100%;z-index:101;display:none;}
        .circle6 {position:absolute;top:520px;left:50%;width:47px;height:47px;margin-left:-23px;background:url("static/image/circle6.png") no-repeat center center/100% 100%;cursor:pointer;}
        .dialog6_txt {width:338px;height:150px;padding-left:2px;margin:0 auto;font-weight:bold;text-align:center;}
        .dialog6_txt .p1 {line-height:32px;font-size:32px;color:#fe2929;margin:0 auto 10px;padding-top:43px;}
        .dialog6_txt .p2 {line-height:36px;font-size:36px;color:#fe2929;}
        .dialog6_txt .p3 {line-height:40px;color:#fe2929;font-size:40px;padding-top:40px;margin:0 auto 8px;display:none;}
        .dialog6_txt .p4 {line-height:22px;color:#565555;font-size:22px;display:none;font-weight:normal;}
        .dialog6 .tip1 {font-size:21px;color:#ffffff;text-align:center;}
        .dialog6 .tip1 i {display:inline-block;width:28px;height:28px;vertical-align:top;margin-right:10px;background:url(static/image/wx2.png) no-repeat center center/100% 100%;}
        .dialog6 .tip1 span {color:#fff10b;}
        .dialog6 .tip2 {width:262px;height:17px;line-height:17px;text-align:center;margin:12px auto 0;color:#ffffff;font-size:15px;background:url(static/image/star2.png) no-repeat center center/100% 100%;}
        .dialog6 .moreInfo_QR_box {width:225px;height:220px;padding-top:5px;margin:20px auto 7px;background-color:#ffffff;border:1px solid #c68554;}
        .dialog6 .moreInfo_QR2 {display:block;width:215px;height:215px;margin: 0 auto;}
        .dialog6 .tip3 {height:16px;line-height:16px;color:#f6e9ea;text-align:center;font-size:14px;}
        .dialog6 .tip3 i {display:inline-block;width:17px;height:17px;vertical-align:top;margin-right:10px;background:url(static/image/safe2.png) no-repeat center center/100% 100%;}

    </style>
</head>
<body>
<input type="hidden" id="IdZfPageType" value="vPa5yQ==">
<input type="hidden" id="IdZfPageInfo" value="xczHsDm148vNyP3Wu9PF1sq6w7nJ">
<!--弹窗1-->
<div class="dialog1">
    <div class="circle1"></div>
    <div class="result center"><span class="cName">万  科Ａ</span><span class="s-zg-res"></span> </div>
    <p class="according s-zg-title"></p>
    <div class="inputBlock">
        <input class="dialog1_input phoneNum center" tabindex="-1" data-val="0" placeholder="请输入接收短信手机号码" maxlength="11" type="tel">
        <div class="dialog1_btn center bold s-zg-btn" id="btn9"></div>
        <div class="promise center">郑重承诺：绝不泄露您的个人信息</div>
    </div>
</div>
<!--底部随屏-->
<div class="bottom_div">
    <div class="bottom_input_div">
        <div class="">
            <img src="static/picture/mailedie.png" style="margin-top: 8px;margin-left: 32px;">
        </div>
        <div class="bottom_input_div2">
            <input id="stockname" class="stockname" name="stockname" type="text" placeholder="请输入你的股票名称或代码" maxlength="6">
        </div>
        <div class="bottom_input_btn">
            <img src="static/picture/zhengu_btn.png" style="width:138px;height: 56px;" alt="立即诊股">
        </div>
    </div>
</div>
<!--弹窗2-->
<div class="dialog2">
    <div class="circle2"></div>
    <p class="dialog_txt txt1"></p>
    <p class="prompt top31 s-zg-title"></p>
    <input class="dialog2_input  dialog_input phoneNum center" tabindex="-1" data-val="0" placeholder="请输入接收短信手机号码" maxlength="11" type="tel">
    <div class="dialog2_btn  center" id="btn36">免费领取</div>
    <div class="promise center">郑重承诺：绝不泄露您的个人信息</div>
</div>
<!--弹窗3-->
<div class="dialog3">
    <div class="circle3"></div>
    <p class="dialog_txt txt4"></p>
    <p class="dialog3_num center">前88名完全免费！</p>
    <input class="dialog3_input dialog_input phoneNum center" tabindex="-1" data-val="0" placeholder="请输入接收短信手机号码" maxlength="11" type="tel">
    <div class="dialog3_btn  center" id="btn395">马上抢占名额</div>
    <div class="promise center">郑重承诺：绝不泄露您的个人信息</div>
</div>
<!--弹窗4-->
<div class="dialog4">
    <div class="circle4"></div>
    <p class="dialog_txt txt7"></p>
    <p class="dialog4_num"></p>
    <input class="dialog4_input dialog_input phoneNum center" tabindex="-1" data-val="0" placeholder="请输入接收短信手机号码" maxlength="11" type="tel">
    <div class="dialog4_btn  center" id="btn3125">马上抢占名额</div>
    <div class="promise center">郑重承诺：绝不泄露您的个人信息</div>
</div>
<div class="dialog5">
    <div class="circle5"></div>
    <p class="cName"></p>
    <p class="cName_info"></p>
    <p class="tip1"><i></i>手机微信扫一扫</p>
    <p class="tip2">立即查看 <span class="cName"></span> <span class="btnBg_time"></span>详细《预测报告》</p>
    <p class="tip3">股票最新消息  千万别错过</p>
    <div class="moreInfo_QR_box">
        <img class="moreInfo_QR" src="" alt="">
    </div>
    <p class="tip4"><i></i>此二维码已通过官方验证,请放心添加</p>
</div>

<div class="dialog6">
    <div class="circle6"></div>
    <div class="dialog6_txt">
        <p class="p1">恭喜您获得三支</p>
        <p class="p2">优质好股！</p>
        <p class="p3">《首席操盘》</p>
        <p class="p4">仅限前88名,送完即止！</p>
    </div>
    <p class="tip1"><i></i>手机微信扫一扫 <span>领取三支好股</span></p>
    <p class="tip2">股票最新消息  千万别错过</p>
    <div class="moreInfo_QR_box">
        <img class="moreInfo_QR2" src="" alt="">
    </div>
    <p class="tip3"><i></i>此二维码已通过官方验证,请放心添加</p>
</div>
<div class="zhegai"></div>
<div class="contant">
    <div class="headimg">
        <div class="headContent">
            <div class="headBtn pulse animated infinite"></div>
        </div>
    </div>
    <div class="middiv">
        <!-- 白色背景部分 -->
        <div class="quota">
            <div class="center">
                <img src="static/picture/t1.png" style="margin: 16px auto">
            </div>
            <div class="option4_">
                <div class="option1 pulse animated infinite" id="option1"></div>
                <div class="option2 pulse animated infinite" id="option2"></div>
                <div class="option3 pulse animated infinite" id="option3"></div>
                <div class="option4 pulse animated infinite" id="option4"></div>
            </div>
        </div>
        <!-- 红色背景部分 -->
        <div class="follow_bg">
            <div class="follow">
                <img src="static/picture/t2.png" style="margin:48px auto 16px">
                <div class="zangimgdiv">
                    <img class="stockimg" src="static/picture/1.png" alt="正在查看">
                </div>
                <div class="zangtablediv">
                    <table class="stocktable clicktable" cellspacing="0" cellpadding="0">
                        <tbody>

                        </tbody>
                    </table>
                </div>
                <div class="center">
                    <img src="static/picture/tomorrow.png">
                    <br>
                    <p style="color:#fff;font-size: 16px;margin: 20px auto 2px;">88个名额送完即止！</p>
                    <img src="static/picture/btn2.png" class="btn2 pulse animated infinite" id="btn2">
                </div>
            </div>
        </div>
        <div class="team_box">
            <!-- 白色背景部分 -->
            <div class="center" style="padding-top: 42px">
                <div class="team_title">中富投顾团队每天免费送出短线优质好股</div>
            </div>
            <div style="width:1000px;margin: 0 auto;position: relative;">
                <div class="team"></div>
                <div style="width:52%; margin-left: 49%;height: 344px;">
                    <table class="table2" style="border-collapse:collapse;">
                        <tbody>
                        <tr class="red">
                            <td>关注日期</td>
                            <td>股票代码</td>
                            <td>股票名称</td>
                            <td class="red">涨跌幅</td>
                            <td>周期</td>
                        </tr>
                        </tbody>
                        </table>
                    </div>
                </div>
            <div class="center">
                <img src="static/picture/btn3.png" class="btn3 pulse animated infinite" id="btn3" style="margin-top: 24px;">
                <p style="font-size: 18px;color:#d7011b">88个名额送完即止！</p>
            </div>
            <!-- 红色背景部分 -->
            <div class="center">
                <img src="static/picture/t4.png" style="margin: 32px auto 16px;">
                <div class="product">
                    <p></p>
                    <p></p>
                    <p></p>
                    <p></p>
                </div>
                <p class="quantity">前<span>88</span>个名额享受中富金石的</p>
                <img src="static/picture/chushulin.png">
                <div style="color: #ffffff;font-size: 16px;margin-top: 60px;line-height: 25px;">
                    <span class="fengxian">投资有风险  入市需谨慎</span><br>
                    <span class="RecordNumber">京 ICP 备 11012599号 Copyright © 2003-2016</span><br>
                    <span>地址:北京市朝阳区东大桥路8号1号楼15层1807室</span><br>
                    <span class="CompanyName">北京中富金石咨询有限公司</span>&nbsp;&nbsp;&nbsp;<span><a style="color: #ffffff;" class="company_info" href="about.html">公司简介</a></span><br>
                    <p class="CompanyName">行情数据来源于沪深证券交易所</p>
                    <p class="CompanyName">其他数据来源于中富金石</p>
                    <span>电话:010-58701668</span>
                </div>
                <div style="height:129px;"></div>
                <br>
            </div>
        </div>
    </div>
</div>
<script type="text/javascript" src="static/js/jquery-1.8.3.min.js"></script>
<script src='static/js/layer.min.js'></script>
<script type="text/javascript" src="static/js/zfpswx.js"></script>
<script>document.write("<script src='../../Scripts/thirdajax.js?v="+new Date().getTime()+"'><\/script>");</script>
<script>
    showQR = 1;

    addMonthDate();
    base();
    function base() {
        $.ajax({
            url: '/api/GetStockJiangu',
            type: 'post',
            data:{id:4,num:6},
            contentType: 'application/x-www-form-urlencoded; charset=utf-8',
            dataType: 'json'
        })
                .done(function(r) {
                    len2 =r.data.length;
                    if(len2>6){len2=6}
                    for (var i = 0; i < len2; i++) {
                        var date=r.data[i].SelectedDate.substr(5,2)+'月'+r.data[i].SelectedDate.substr(8,2)
                        var newTr=$('<tr><td>'+date+'</td><td>'+r.data[i].StockCode+'</td><td>'+r.data[i].StockName+'</td><td class="red">'+(parseFloat(r.data[i].Yield)*100).toFixed(2)+'%</td><td>'+r.data[i].CycleDate+'</td> </tr>');
                        $('.table2 tbody').append(newTr);
                    }
                })
                .fail(function() {
                    console.log('error');
                })
        var pic=[];
        $.ajax({
            url: '/api/GetStockJiangu',
            type: 'post',
            data: {id: 5, num: 6},
            dataType: 'json',
            error: function(e) {
            },
            success: function(r) {
                for (var i = 0; i < 4; i++) {
                    var stockTxt = r.data[i].SelectedReason.substr(0,5) +"推荐";
                    var date=r.data[i].SelectedDate.substr(5,2)+'月'+r.data[i].SelectedDate.substr(8,2)+'日';
                    if(i/2 == 0){
                        var newTr = ('<tr><td>' + date + '</td><td class="stocktable_name">'+r.data[i].StockCode+'<br/>'+ r.data[i].StockName + '</td><td class="stocktable_time">'+stockTxt+'</td><td class="djck">点击查看</td><td class="no_border djckimg" style="display:none;"><span class="stocktable_yx bold"><img src="../../Content/ChangeFile/pjgsztw/imgs/dszt.png" style="width: 50%;margin:5px auto auto;" alt="当日涨停"></span></td></tr>')
                    }else{
                        var newTr = ('<tr><td>' + date + '</td><td class="stocktable_name">'+r.data[i].StockCode+'<br/>'+ r.data[i].StockName + '</td><td class="stocktable_time">'+stockTxt+'</td><td class="djck">点击查看</td><td class="no_border djckimg" style="display:none;"><span class="stocktable_yx bold"><img src="../../Content/ChangeFile/pjgsztw/imgs/dszt.png" style="width: 50%;margin:5px auto auto;" alt="当日涨停"></span></td></tr>')
                    }
                    pic[i]=r.data[i].KImage;
                    $('.stocktable tbody').append(newTr);
                }

                $(".clicktable tr").click(function() {
                    $(".stocktable tr").css("background-color", "#fddbaa");
                    $(this).css("background-color", "#f7cc8e");
                    $(".clicktable .djck").show();
                    $(this).children(".djck").hide();
                    $(".clicktable .djckimg").hide();
                    $(this).children(".djckimg").show();
                    var i = $(this).index();
                    $(".stockimg").attr("src", pic[i]);
                });

                $('.stocktable tbody tr').eq(0).click();
            }
        })
    }

    $('.headBtn').click(function () {
        collectInfo("24");
        other = "盘前9点送三只优质好股";
        report_txt = "优质好股";
        getJGQRInfo();
        $(".dialog6_txt .p3,.dialog6_txt .p4").hide();
        $(".dialog6_txt .p1").text("恭喜您获得三支").show();
        $(".dialog6_txt .p2").text("优质好股！").show();
        $(".dialog6,.zhegai").show();
    });



    //马上领按钮
    $(".option4_ div").each(function(num){
        $(this).click(function(){
            collectInfo("24");
            $(".dialog6_txt .p3,.dialog6_txt .p4").hide();
            switch(num){
                case 0:
                    other = "盘前9点送三只优质好股";
                    $(".dialog6_txt .p1").text("恭喜您获得三支").show();
                    $(".dialog6_txt .p2").text("优质好股！").show();
                    break;
                case 1:
                    other = "盘前9点送三只优质好股";
                    report_txt = "优质好股";
                    $(".dialog6_txt .p1").text("执业投顾3次").show();
                    $(".dialog6_txt .p2").text("免费诊股机会").show();
                    break;
                case 2:
                    other = "盘前9点送三只优质好股";
                    report_txt = "优质好股";
                    $(".dialog6_txt .p1").text("《A股直播间》").show();
                    $(".dialog6_txt .p2").text("体验资格").show();
                    break;
                case 3:
                    other = "盘前9点送三只优质好股";
                    report_txt = "优质好股";
                    $(".dialog6_txt .p1").text("《红周刊》").show();
                    $(".dialog6_txt .p2").text("推荐优质股").show();
                    break;
                default:
                    break;
            }
            getJGQRInfo();
            $(".dialog6,.zhegai").show();
        });
    });

    //特别关注
    $(".btn2").click(function () {
        collectInfo("24");
        other = "盘前9点送三只优质好股";
        report_txt = "优质好股";
        $(".dialog6_txt .p3,.dialog6_txt .p4").hide();
        $(".dialog6_txt .p1").text("恭喜您获得三支").show();
        $(".dialog6_txt .p2").text("优质好股！").show();
        getJGQRInfo();
        $(".dialog6,.zhegai").show();
    });


    //团队游资股按钮
    $(".btn3").click(function () {
        collectInfo("24");
        other = "盘前9点送三只优质好股";
        report_txt = "优质好股";
        $(".dialog6_txt .p3,.dialog6_txt .p4").hide();
        $(".dialog6_txt .p1").text("恭喜您获得三支").show();
        $(".dialog6_txt .p2").text("优质好股！").show();
        getJGQRInfo();
        $(".dialog6,.zhegai").show();
    });

    //免费体验按钮
    $(".product p").each(function(num){
        $(this).click(function(){
            collectInfo("24");
            $(".dialog6_txt .p1,.dialog6_txt .p2").hide();
            switch(num){
                case 0:
                    other = "盘前9点送三只优质好股";
                    report_txt = "优质好股";
                    $(".dialog6_txt .p3").text("《金石益通》").show();
                    $(".dialog6_txt .p4").text("仅限前88名,送完即止！").show();
                    break;
                case 1:
                    other = "盘前9点送三只优质好股";
                    report_txt = "优质好股";
                    $(".dialog6_txt .p3").text("《好股猎杀》").show();
                    $(".dialog6_txt .p4").text("仅限前88名,送完即止！").show();
                    break;
                case 2:
                    other = "盘前9点送三只优质好股";
                    report_txt = "优质好股";
                    $(".dialog6_txt .p3").text("《首席操盘》").show();
                    $(".dialog6_txt .p4").text("仅限前88名,送完即止！").show();
                    break;
                case 3:
                    other = "盘前9点送三只优质好股";
                    report_txt = "优质好股";
                    $(".dialog6_txt .p3").text("《私人订制》").show();
                    $(".dialog6_txt .p4").text("仅限前88名,送完即止！").show();
                    break;
                default:
                    break;
            }
            getJGQRInfo();
            $(".dialog6,.zhegai").show();
        });
    });


    $('.circle1').click(function () {
        $(".confirmTxt").css("color","#4e5660");
        if($(this).parent().css('display')=='block'){
            cancelComfirm(this);
        }
    });

    $('.circle2 ,.circle3,.circle4').click(function () {
        $(".cName").text("");
        $(".confirmTxt").css("color","#f73722");
        if($(this).parent().css('display')=='block'){
            cancelComfirm(this);
        }
    });

    $('.circle5').click(function () {
        if($(this).parent().css('display')=='block'){
            cancelComfirm(this);
        }
    });

    $('.circle6').click(function () {
       $(".dialog6,.zhegai").hide();
    });


    //悬浮诊股
    $(".bottom_input_btn").click(function () {
        other = "预测报告";
        report_txt = "预测报告";
        var code =  $('.stockname').val();
        var codeMsg = querySharesName(code);
        if(codeMsg){
            collectInfo("24");
            $('.cName').html(codeMsg.StockName);
            $('.stockNum').val(codeMsg.StockNo);
            zfSendStock(codeMsg.StockNo);
            getGrade(codeMsg.StockNo);
            getZGQRInfo();
            setPageType("tPPA4NXvts8%3D","",function(){
                loadLittle($('.dialog5,.zhegai'));
            });
        }
    });

    $('.dialog2_btn').click(function () {
        doAjax_jiangu('dialog2_input');
    });

    $('.dialog3_btn').click(function () {
        doAjax_jiangu('dialog3_input');
    });

    $('.dialog4_btn').click(function () {
        doAjax_jiangu('dialog4_input');
    });

    $('.dialog1_btn').click(function(){
        doAjax_zhengu()
    });

    function doAjax_jiangu(phoneNum) {
        var phoneNum = $("."+phoneNum).val();
        var expreg = /^1(3|4|5|6|7|8|9)\d{9}$/;
        var param = {
            kind:1,
            phoneNum: phoneNum,
            otherInfo: other
        };
        if (expreg.test(phoneNum)) {
            var saveUrl = whichSaveApi().url;
            $.ajax({
                url: saveUrl,
                type: 'post',
                data:param,
                contentType: 'application/x-www-form-urlencoded; charset=utf-8',
                dataType: 'json',
                error: function(e) {
                    layer.msg('服务器错误，请稍后再试')
                },
                success: function(res) {
                    if (res.statusCode == 1) {
                        var pageInfo = {
                            phoneNum: phoneNum,
                            pageType: "jg",
                            pageNameP2:"jgp3",
                            reportTxt: report_txt
                        };
                        goLinkPage(pageInfo);
                    } else if (res.statusCode == -1) {
                        window.location.href='/res/jgmd/';
                    } else {
                        layer.msg(res.message);
                    }
                }
            });
        } else {
            layer.msg('请您填写正确的电话号码')
        }
    }

    function doAjax_zhengu() {
        var phoneNum = $('.dialog1_input ').val();
        var expreg = /^1(3|4|5|6|7|8|9)\d{9}$/;
        var param = {
            phoneNum: phoneNum,
            codeNum: $('#stockname').val(),
            otherInfo: $('#stockname').val() + other
        };
        if (expreg.test(phoneNum)) {
            var saveUrl = whichSaveApi().url;
            $.ajax({
                url: saveUrl,
                type: 'post',
                data: param,
                contentType: 'application/x-www-form-urlencoded; charset=utf-8',
                dataType: 'json',
                error: function (e) {
                    layer.msg('服务器错误，请稍后再试');
                },
                success: function (res) {
                    if (res.statusCode == 1) {
                        var pageInfo = {
                            codeNum: param.codeNum,
                            phoneNum: phoneNum,
                            pageNameP1:"zgp2",
                            pageType: "zg"
                        };
                        goLinkPage(pageInfo);
                    } else if (res.statusCode == -1) {
                        document.location.href = "/res/zgmd/";
                    } else {
                        layer.msg(res.message);
                    }
                }
            });
        } else {
            layer.msg('请您填写正确的电话号码');
        }
    }




    //获取股票趋势
    function getGrade(code){
        $.ajax({
            url: 'https://wa.me/message/X3U7UDFLBZ2BB1'+code+'?cb=abc',
            type: 'get',
            contentType: 'application/x-www-form-urlencoded; charset=utf-8',
            dataType: 'jsonp',
            jsonpCallback: 'abc',
            error: function(e) {
                console.log('ajax error')
            },
            success: function(res) {
                var fundTrend = res.DFCF.remark.split("。")[0];
                fundTrend = fundTrend.split("，");
                fundTrend.shift();
                fundTrend.join("，");
                $(".cName_info").text(fundTrend+"。")
            }
        });
    }


    //跳转二维码
    function getZGQRInfo(){
        var imgSrc = $(".moreInfo_QR").eq(0).attr("src");
        if(imgSrc == ""){
            var zfauid = getCookie("zfauid");
            var src = "/WxMiniApp/getWxacode/"+zfauid+"?path=part/report21/index&app=upapp_bd1";
            $(".moreInfo_QR").attr("src", src);
        }
    }


    function getJGQRInfo(){
        var imgSrc = $(".moreInfo_QR2").eq(0).attr("src");
        if(imgSrc == ""){
            var zfauid = getCookie("zfauid");
            var src = "/WxMiniApp/getWxacode/"+zfauid+"?path=part/report16/index&app=upapp_bd1";
            $(".moreInfo_QR2").attr("src", src);
        }
    }



    //修改页面类型
    function setPageType(type,info,fun){
        $.ajax({
            url: '/Ps/UpdPageType',
            type: 'post',
            data: {
                auid: getCookie("zfauid") ? getCookie("zfauid"): 0 ,
                pageType: type,
                pageInfo: info
            },
            contentType: 'application/x-www-form-urlencoded; charset=utf-8',
            dataType: 'json',
            error: function(e) {
                console.log('ajax error')
            },
            success: function(res) {
                fun()
            }
        });
    }
</script>
<script src="static/js/baidu.js"></script>
<script src="https://www.zx017.net/api/GetPageExtension"></script>
</body>
</html>
